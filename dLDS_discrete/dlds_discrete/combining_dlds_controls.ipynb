# %%
from models import DLDSwithControlModel
#from datasets import DLDSwithControlDataset
#import main_functions as mf
from importlib import reload
import plotly.express as px

# %%
model = DLDSwithControlModel()

# generate toy data
X = model.datasets.generate_data(1000, sigma=0.01, fix_point_change=True, eigenvalue_radius=0.98)

# %%
# visualize the data
px.line(X.T)
